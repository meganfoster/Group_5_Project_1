# %%
import requests
from pprint import pprint
import os
import csv
import pandas as pd
import numpy as np
from itertools import chain

omdb_key = "9b9d69c4"

# %%
top_grossing_csv = 'Top_Grossing_Films.csv'
top_grossing_df = pd.read_csv(top_grossing_csv)
top_grossing_df
# Out:
#     Year  Movie ID                                      Movie Title  \
# 0   1927    287262  The Battles of the Coronel and Falkland Islands
# 1   1928    173689                               Lights of New York
# 2   1929     65203                              The Broadway Melody
# 3   1930    166307                                       Tom Sawyer
# 4   1931      3035                                     Frankenstein
# ..   ...       ...                                              ...
# 88  2015    140607                     Star Wars: The Force Awakens
# 89  2016    271110                       Captain America: Civil War
# 90  2017    181808                         Star Wars: The Last Jedi
# 91  2018    299536                           Avengers: Infinity War
# 92  2019    299534                                Avengers: Endgame
#
#        Revenue
# 0      6241682
# 1      1200000
# 2      4358000
# 3     11000000
# 4     12000000
# ..         ...
# 88  2068223624
# 89  1153296293
# 90  1332539889
# 91  2046239637
# 92  2797800564
#
# [93 rows x 4 columns]

# %%
url = f"http://www.omdbapi.com/?apikey={omdb_key}&t="

# %%
top_grossing_df['Movie Genre'] = ""
top_grossing_df['Runtime'] = ""
top_grossing_df['Actors'] = ""
top_grossing_df['IMDB Rating'] = ""
top_grossing_df['Rotten Tomatoes Rating'] = ""

top_grossing_df.head()
# Out:
#    Year  Movie ID                                      Movie Title   Revenue  \
# 0  1927    287262  The Battles of the Coronel and Falkland Islands   6241682
# 1  1928    173689                               Lights of New York   1200000
# 2  1929     65203                              The Broadway Melody   4358000
# 3  1930    166307                                       Tom Sawyer  11000000
# 4  1931      3035                                     Frankenstein  12000000
#
#   Movie Genre Runtime Actors IMDB Rating Rotten Tomatoes Rating
# 0
# 1
# 2
# 3
# 4

# %%
top_grossing_df = top_grossing_df.replace(to_replace = ["La figlia di Frankenstein"], value ="Lady Frankenstein")
top_grossing_df = top_grossing_df.replace(to_replace = ["Harry Potter and the Philosopher's Stone"], value ="Harry Potter and the Sorcerer's Stone")

#df.replace(to_replace =["La figlia di Frankenstein"],  value ="Lady Frankenstein")

# %%
for index, row in top_grossing_df.iterrows():
    
    query_url = url + (row['Movie Title'])
    
    response_url = requests.get(query_url).json()
    
    try:
        top_grossing_df.loc[index, 'Movie Genre'] = response_url['Genre']
        top_grossing_df.loc[index, 'Actors'] = response_url['Actors']
        top_grossing_df.loc[index, 'Runtime'] = response_url['Runtime']
        top_grossing_df.loc[index, 'IMDB Rating'] = response_url['Ratings'][0]['Value']
        top_grossing_df.loc[index, 'Rotten Tomatoes Rating'] = response_url['Ratings'][1]['Value']
        
    except (KeyError,IndexError):
        print(f" Problem with this film - '{row['Movie Title']}'")
# Out:
#  Problem with this film - 'The Battles of the Coronel and Falkland Islands'
#  Problem with this film - 'Lights of New York'
#  Problem with this film - 'Tom Sawyer'
#  Problem with this film - 'Seeds of Destiny'
#  Problem with this film - 'Spartacus'
#  Problem with this film - 'Hawaii'
# 11                    93%
# 12                    91%
# 13                   100%
# 14                   100%
# 15                    90%
# 16                    81%
# 17                    83%
# 18                    85%
# 19
# 20                    74%
# 21                   100%
# 22                    63%
# 23                    84%
# 24                    51%
# 25                    43%
# 26                    80%
# 27                    99%
# 28                    93%
# 29                    89%
# 30                    95%
# 31                    80%
# 32                    86%
# 33
# 34                    98%
# 35                    74%
# 36                    95%
# 37                    99%
# 38                    83%
# 39
# 40                    94%
# 41                    93%
# 42                    90%
# 43                    67%
# 44
# 45                    98%
# 46                    83%
# 47                    89%
# 48                    98%
# 49

# %%
actor_list_df = top_grossing_df[['Year','Movie Title', 'Actors']]
actor_list_df
# Out:
#     Year                                      Movie Title  \
# 0   1927  The Battles of the Coronel and Falkland Islands
# 1   1928                               Lights of New York
# 2   1929                              The Broadway Melody
# 3   1930                                       Tom Sawyer
# 4   1931                                     Frankenstein
# ..   ...                                              ...
# 88  2015                     Star Wars: The Force Awakens
# 89  2016                       Captain America: Civil War
# 90  2017                         Star Wars: The Last Jedi
# 91  2018                           Avengers: Infinity War
# 92  2019                                Avengers: Endgame
#
#                                                Actors
# 0
# 1   Helene Costello, Cullen Landis, Mary Carr, Whe...
# 2               Charles King, Anita Page, Bessie Love
# 3   Johnny Whitaker, Celeste Holm, Warren Oates, J...
# 4   Colin Clive, Mae Clarke, John Boles, Boris Kar...
# ..                                                ...
# 88  J.J. Abrams, John Boyega, Anthony Carboni, Gwe...
# 89  Chris Evans, Robert Downey Jr., Scarlett Johan...
# 90                                       Taylor Clark
# 91  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 92  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
#
# [93 rows x 3 columns]

# %%
def column_splitter(column_to_split):
    return list(chain.from_iterable(column_to_split.str.split(',')))

lengths = actor_list_df['Actors'].str.split(',').map(len)

actor_list_df = pd.DataFrame({
    'Year': np.repeat(actor_list_df['Year'],lengths),
    'Movie Title': np.repeat(actor_list_df['Movie Title'],lengths),
    'Actors': column_splitter(actor_list_df['Actors'])
})

actor_list_df.head(50)
# Out:
#     Year                                      Movie Title               Actors
# 0   1927  The Battles of the Coronel and Falkland Islands
# 1   1928                               Lights of New York      Helene Costello
# 1   1928                               Lights of New York        Cullen Landis
# 1   1928                               Lights of New York            Mary Carr
# 1   1928                               Lights of New York       Wheeler Oakman
# 2   1929                              The Broadway Melody         Charles King
# 2   1929                              The Broadway Melody           Anita Page
# 2   1929                              The Broadway Melody          Bessie Love
# 3   1930                                       Tom Sawyer      Johnny Whitaker
# 3   1930                                       Tom Sawyer         Celeste Holm
# 3   1930                                       Tom Sawyer         Warren Oates
# 3   1930                                       Tom Sawyer            Jeff East
# 4   1931                                     Frankenstein          Colin Clive
# 4   1931                                     Frankenstein           Mae Clarke
# 4   1931                                     Frankenstein           John Boles
# 4   1931                                     Frankenstein        Boris Karloff
# 5   1932                                      Grand Hotel          Greta Garbo
# 5   1932                                      Grand Hotel       John Barrymore
# 5   1932                                      Grand Hotel        Joan Crawford
# 5   1932                                      Grand Hotel        Wallace Beery
# 6   1933                                        King Kong          Naomi Watts
# 6   1933                                        King Kong           Jack Black
# 6   1933                                        King Kong         Adrien Brody
# 6   1933                                        King Kong   Thomas Kretschmann
# 7   1934                        The Man Who Knew Too Much        James Stewart
# 7   1934                        The Man Who Knew Too Much            Doris Day
# 7   1934                        The Man Who Knew Too Much     Brenda de Banzie
# 7   1934                        The Man Who Knew Too Much        Bernard Miles
# 8   1935                             Mutiny on the Bounty     Charles Laughton
# 8   1935                             Mutiny on the Bounty          Clark Gable
# 8   1935                             Mutiny on the Bounty        Franchot Tone
# 8   1935                             Mutiny on the Bounty       Herbert Mundin
# 9   1936                                     Modern Times      Charles Chaplin
# 9   1936                                     Modern Times     Paulette Goddard
# 9   1936                                     Modern Times        Henry Bergman
# 9   1936                                     Modern Times        Tiny Sandford
# 10  1937                  Snow White and the Seven Dwarfs           Roy Atwell
# 10  1937                  Snow White and the Seven Dwarfs      Stuart Buchanan
# 10  1937                  Snow White and the Seven Dwarfs    Adriana Caselotti
# 10  1937                  Snow White and the Seven Dwarfs        Eddie Collins
# 11  1938                       You Can't Take It with You          Jean Arthur
# 11  1938                       You Can't Take It with You     Lionel Barrymore
# 11  1938                       You Can't Take It with You        James Stewart
# 11  1938                       You Can't Take It with You        Edward Arnold
# 12  1939                               Gone with the Wind      Thomas Mitchell
# 12  1939                               Gone with the Wind       Barbara O'Neil
# 12  1939                               Gone with the Wind         Vivien Leigh
# 12  1939                               Gone with the Wind         Evelyn Keyes
# 13  1940                                        Pinocchio            Mel Blanc
# 13  1940                                        Pinocchio           Don Brodie

# %%
test = f"http://www.omdbapi.com/?apikey={omdb_key}&t=Jaws"
test_response = requests.get(test).json()
pprint(test_response)
# Out:
# {'Actors': 'Roy Scheider, Robert Shaw, Richard Dreyfuss, Lorraine Gary',
#  'Awards': 'Won 3 Oscars. Another 11 wins & 19 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Jul 2000',
#  'Director': 'Steven Spielberg',
#  'Genre': 'Adventure, Thriller',
#  'Language': 'English',
#  'Metascore': '87',
#  'Plot': "When a killer shark unleashes chaos on a beach community, it's up to "
#          'a local sheriff, a marine biologist, and an old seafarer to hunt the '
#          'beast down.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmVmODY1MzEtYTMwZC00MzNhLWFkNDMtZjAwM2EwODUxZTA5XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '98%'},
#              {'Source': 'Metacritic', 'Value': '87/100'}],
#  'Released': '20 Jun 1975',
#  'Response': 'True',
#  'Runtime': '124 min',
#  'Title': 'Jaws',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Peter Benchley (screenplay), Carl Gottlieb (screenplay), Peter '
#            'Benchley (based on the novel by)',
#  'Year': '1975',
#  'imdbID': 'tt0073195',
#  'imdbRating': '8.0',
#  'imdbVotes': '531,727'}

# %%
#df.to_csv(r'Path where you want to store the exported CSV file\File Name.csv', index = False)

top_grossing_df.to_csv('Final_Grossing_Data.csv', index = False)
